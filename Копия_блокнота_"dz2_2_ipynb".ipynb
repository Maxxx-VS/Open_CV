# %% [markdown]
# <a href="https://colab.research.google.com/github/Maxxx-VS/Open_CV/blob/master/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22dz2_2_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1 Посмотрите на изображение fox2.jpg. Подберите цветовой формат и приведите изображение к нормальному виду.

# %%
# !pip install opencv-python

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread('/content/fox2.JPG')
img = cv2.resize(img, (img.shape[1] // 3 ,img.shape[0] // 3))

cv2_imshow(img)

img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=416x275>
# <PIL.Image.Image image mode=RGB size=416x275>

# %% [markdown]
# 2 Посмотрите на изображение fox3.jpg. Подберите цветовой формат и приведите изображение к нормальному виду.

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread('/content/fox3.JPG')
img = cv2.resize(img, (img.shape[1] // 3 ,img.shape[0] // 3))

cv2_imshow(img)

img = cv2.cvtColor(img, cv2.COLOR_HSV2RGB)

cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=416x276>
# <PIL.Image.Image image mode=RGB size=416x276>

# %% [markdown]
# 3 Посмотрите на изображение fox4.jpg. Подберите цветовой формат и приведите изображение к нормальному виду.

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread('/content/fox4.JPG')
img = cv2.resize(img, (img.shape[1] // 3 ,img.shape[0] // 3))

cv2_imshow(img)

img = cv2.cvtColor(img, cv2.COLOR_LAB2RGB)

cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=415x275>
# <PIL.Image.Image image mode=RGB size=415x275>

# %% [markdown]
# ! Ухудшение качества изображения не учитывается. Уменьшайте изображение, если необходимо. !
